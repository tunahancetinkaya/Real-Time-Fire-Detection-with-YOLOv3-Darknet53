# %%
import cv2
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15379, done.
# remote: Total 15379 (delta 0), reused 0 (delta 0), pack-reused 15379
# Receiving objects: 100% (15379/15379), 14.01 MiB | 6.75 MiB/s, done.
# Resolving deltas: 100% (10341/10341), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/darknet

# %%
# %cd data
# Out:
# /content/drive/My Drive/darknet/data

# %%
# !python get_paths.py --target "/content/drive/MyDrive/Colab Notebooks/dataset/jpg"

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

print("Building. . . It might take 2-3 minutes")

# !make &> build_log.txt
# Out:
# Building. . . It might take 2-3 minutes

# %%
# !wget "https://pjreddie.com/media/files/darknet53.conv.74"
# Out:
# --2021-12-20 17:37:18--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  21.4MB/s    in 8.4s
#
# 2021-12-20 17:37:27 (18.6 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
import cv2

# %%
# !./darknet detector train /content/drive/MyDrive/darknet/data/fire.data /content/drive/MyDrive/darknet/cfg/yolov3.cfg /content/drive/MyDrive/darknet/backup/yolov3_last.weights -dont_show -i 0 -map
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.022087, iou_loss = 0.000000, total_loss = 0.022087
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.022537, iou_loss = 0.000000, total_loss = 0.022537
#  total_bbox = 8710, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1055 iterations)
#  961: 1.293319, 1.208272 avg loss, 0.000853 rate, 18.016816 seconds, 61504 images, 6.733068 hours left
# Loaded: 0.000068 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.690803), count: 6, class_loss = 1.475243, iou_loss = 0.482102, total_loss = 1.957344
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.531077), count: 1, class_loss = 0.242826, iou_loss = 0.195701, total_loss = 0.438527
# ...

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline
  image=cv2.imread(path)
  height,width=image.shape[:2]
  resized_image=cv2.resize(image,(3*width,3*height),interpolation=cv2.INTER_CUBIC)
  fig=plt.gcf()
  fig.set_size_inches(18,10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image,cv2.COLOR_BGR2RGB))
  plt.show()

# %%
import cv2
# !./darknet detector test /content/drive/MyDrive/darknet/data/fire.data /content/drive/MyDrive/darknet/cfg/yolov3.cfg /content/drive/MyDrive/darknet/backup/yolov3_last.weights -thresh 0.1 
imShow('predictions.jpg')

# %%
# !./darknet detector test /content/drive/MyDrive/darknet/data/fire.data /content/drive/MyDrive/darknet/cfg/yolov3.cfg /content/drive/MyDrive/darknet/backup/yolov3_last.weights  /content/drive/MyDrive/darknet/00239.jpg -thresh 0.1 
imShow('predictions.jpg')

# %%
# !./darknet detector test /content/drive/MyDrive/darknet/data/fire.data /content/drive/MyDrive/darknet/cfg/yolov3.cfg /content/drive/MyDrive/darknet/backup/yolov3_last.weights  /content/drive/MyDrive/darknet/00240.jpg -thresh 0.3 
imShow('predictions.jpg')

# %%
# !./darknet detector test /content/drive/MyDrive/darknet/data/fire.data /content/drive/MyDrive/darknet/cfg/yolov3.cfg /content/drive/MyDrive/darknet/backup/yolov3_last.weights  /content/drive/MyDrive/darknet/test1.jpg -thresh 0.1 
imShow('predictions.jpg')

# %%
# !./darknet detector demo /content/drive/MyDrive/darknet/data/fire.data /content/drive/MyDrive/darknet/cfg/yolov3.cfg /content/drive/MyDrive/darknet/backup/yolov3_last.weights video1.mp4 -thresh .1 -out_filename ooout-vid2.avi -dont_show
